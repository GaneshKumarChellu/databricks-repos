# %%
# %fs ls

# %%
dbutils.fs.ls("dbfs:/")

# %%
spark.conf.get("spark.databricks.cluster.profile","")

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql 
Create catalog my_test_catalog
MANAGED LOCATION 'abfss://my-test-catalog@databricksadlsgk.dfs.core.windows.net/';

# %%
dbutils.fs.ls("abfss://my-test-catalog@databricksadlsgk.dfs.core.windows.net/")

# %%
# %sql
use catalog my_test_catalog

# %%
# %sql
CREATE EXTERNAL VOLUME vol_test LOCATION 'abfss://my-test-catalog@databricksadlsgk.dfs.core.windows.net/raw-test/'

# %%
# %sql
SHOW EXTERNAL LOCATIONS;

# %%
# %sql SHOW VOLUMES

# %%
# %fs
ls '/Volumes/my_test_catalog/default/vol_test/'

# %%
display(spark.read.csv('/Volumes/my_test_catalog/default/vol_test/', header = True))
